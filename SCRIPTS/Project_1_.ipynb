# %% [markdown]
# <a href="https://colab.research.google.com/github/juliamuratore/Project1-DS-4002/blob/main/Project_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
jo = pd.read_csv('/content/jo.csv')
sb = pd.read_csv('/content/sb.csv')

# %%
sb.head()
# Out:
#    Unnamed: 0      User Id         Comment Id  \
# 0           0   4382790947  17857495791052843
# 1           1  51746321373  17860182567067690
# 2           2     28408400  18378184846077171
# 3           3    300207646  17992827728271359
# 4           4   5614303926  17934860549695140
#
#                                         Comment Text             Publish Date
# 0                                          The goat!   12/25/2023, 5:55:26 PM
# 1                                           ❤️❤️❤️❤️   12/25/2023, 6:36:52 PM
# 2  Never heard of your husband. Hope he makes a g...  12/25/2023, 11:51:47 PM
# 3        This fit is everything & she is beautiful 🥰   12/26/2023, 3:24:06 AM
# 4                who’s that guy in the second photo?   12/27/2023, 1:32:42 AM

# %%
jo.head()
# Out:
#    Unnamed: 0      User Id         Comment Id  \
# 0           0  56597613313  17908610195809218
# 1           1  56597613313  18026938972723984
# 2           2    236447151  17919327446765056
# 3           3    236447151  17989393328603270
# 4           4    236447151  17968603745528169
#
#                                         Comment Text          Publish Date
# 0                                   Beautiful couple  1/3/2024, 5:05:52 PM
# 1                                   She is the prize  1/3/2024, 5:07:22 PM
# 2  @jariruiz … You are giving yourself & these no...  1/3/2024, 5:09:57 PM
# 3  @jariruiz **only God knows what’s best for her...  1/3/2024, 5:12:15 PM
# 4  @melomatlala … I too like & admire Simone Bile...  1/3/2024, 5:16:24 PM

# %%
sb.columns.to_list()
# Out:
# ['Unnamed: 0', 'User Id', 'Comment Id', 'Comment Text', 'Publish Date']

# %%
sb.count()
# Out:
# Unnamed: 0      600
# User Id         600
# Comment Id      600
# Comment Text    598
# Publish Date    600
# dtype: int64

# %%
jo.count()
# Out:
# Unnamed: 0      600
# User Id         600
# Comment Id      600
# Comment Text    597
# Publish Date    600
# dtype: int64

# %%
sb['Publish Date'] = pd.to_datetime(sb['Publish Date']).dt.date

# %%
sb.head()
# Out:
#    Unnamed: 0      User Id         Comment Id  \
# 0           0   4382790947  17857495791052843
# 1           1  51746321373  17860182567067690
# 2           2     28408400  18378184846077171
# 3           3    300207646  17992827728271359
# 4           4   5614303926  17934860549695140
#
#                                         Comment Text Publish Date
# 0                                          The goat!   2023-12-25
# 1                                           ❤️❤️❤️❤️   2023-12-25
# 2  Never heard of your husband. Hope he makes a g...   2023-12-25
# 3        This fit is everything & she is beautiful 🥰   2023-12-26
# 4                who’s that guy in the second photo?   2023-12-27

# %%
jo['Publish Date'] = pd.to_datetime(jo['Publish Date']).dt.date
jo.head()
# Out:
#    Unnamed: 0      User Id         Comment Id  \
# 0           0  56597613313  17908610195809218
# 1           1  56597613313  18026938972723984
# 2           2    236447151  17919327446765056
# 3           3    236447151  17989393328603270
# 4           4    236447151  17968603745528169
#
#                                         Comment Text Publish Date
# 0                                   Beautiful couple   2024-01-03
# 1                                   She is the prize   2024-01-03
# 2  @jariruiz … You are giving yourself & these no...   2024-01-03
# 3  @jariruiz **only God knows what’s best for her...   2024-01-03
# 4  @melomatlala … I too like & admire Simone Bile...   2024-01-03
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['User Id'].plot(kind='hist', bins=20, title='User Id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Comment Id'].plot(kind='hist', bins=20, title='Comment Id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('Comment Text').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='Unnamed: 0', y='User Id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='User Id', y='Comment Id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['User Id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_6.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Comment Text')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Comment Text', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('User Id')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['Comment Id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Comment Text')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Comment Text', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('Comment Id')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Unnamed: 0']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Unnamed: 0'}, axis=1)
#               .sort_values('Unnamed: 0', ascending=True))
#   xs = counted['Unnamed: 0']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Comment Text')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Comment Text', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Publish Date']
#   ys = series['User Id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('Publish Date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Comment Text')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Comment Text', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Publish Date')
# _ = plt.ylabel('User Id')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_10['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['User Id'].plot(kind='line', figsize=(8, 4), title='User Id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['Comment Id'].plot(kind='line', figsize=(8, 4), title='Comment Id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_13['Comment Text'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_13, x='Unnamed: 0', y='Comment Text', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_14['Comment Text'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_14, x='User Id', y='Comment Text', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['Comment Text'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='Comment Id', y='Comment Text', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
sb['Publish Date'].hist()
# Out:
# <Axes: >

# %%
jo['Publish Date'].hist()
# Out:
# <Axes: >

# %%
sb["Comment Length"]= sb["Comment Text"].str.len()

# %%
sb['Comment Length'].describe()
# Out:
# count     598.000000
# mean       58.306020
# std       122.963171
# min         1.000000
# 25%        15.000000
# 50%        28.000000
# 75%        61.750000
# max      1906.000000
# Name: Comment Length, dtype: float64

# %%
jo["Comment Length"]= jo["Comment Text"].str.len()

# %%
jo['Comment Length'].describe()
# Out:
# count    597.000000
# mean      73.787270
# std       72.792709
# min        1.000000
# 25%       25.000000
# 50%       52.000000
# 75%       98.000000
# max      537.000000
# Name: Comment Length, dtype: float64

# %%
# Creating a scatterplot of comment lengths on each profile
x = sb['Comment Length']
y = jo['Comment Length']
plt.title("Comment Length for Simone Biles' and Jonathan Owens' posts")
plt.xlabel("Simone Biles")
plt.ylabel("Jonathan Owens")
plt.scatter(x, y)
plt.show()

# %%
import seaborn as sns

# %%
sb.corr()
# Out:
# <ipython-input-46-436221da0c6e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb.corr()
#                 Unnamed: 0   User Id  Comment Id  Comment Length
# Unnamed: 0        1.000000 -0.011892    0.002561       -0.016628
# User Id          -0.011892  1.000000   -0.020563        0.056618
# Comment Id        0.002561 -0.020563    1.000000        0.033349
# Comment Length   -0.016628  0.056618    0.033349        1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['User Id'].plot(kind='hist', bins=20, title='User Id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['Comment Id'].plot(kind='hist', bins=20, title='Comment Id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['Comment Length'].plot(kind='hist', bins=20, title='Comment Length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_20.plot(kind='scatter', x='Unnamed: 0', y='User Id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21.plot(kind='scatter', x='User Id', y='Comment Id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22.plot(kind='scatter', x='Comment Id', y='Comment Length', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_23['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['User Id'].plot(kind='line', figsize=(8, 4), title='User Id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25['Comment Id'].plot(kind='line', figsize=(8, 4), title='Comment Id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['Comment Length'].plot(kind='line', figsize=(8, 4), title='Comment Length')
# plt.gca().spines[['top', 'right']].set_visible(False)
