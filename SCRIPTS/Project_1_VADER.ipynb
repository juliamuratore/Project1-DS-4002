# %% [markdown]
# <a href="https://colab.research.google.com/github/juliamuratore/Project1-DS-4002/blob/main/Project_1_VADER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VADER Analysis
# The following script will go through preliminary analysis of the Simone Biles and Jonathan Owens data sets, provide import plots of the data, perform the VADER analysis, and complete an extra visual analysis of text data.

# %%
# importing necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# naming data frames
jo = pd.read_csv('../DATA/jo.csv')
sb = pd.read_csv('../DATA/sb.csv')

# %%
# looking at Simone Biles
sb.head()
# Out:
#    Unnamed: 0      User Id         Comment Id  \
# 0           0   4382790947  17857495791052843
# 1           1  51746321373  17860182567067690
# 2           2     28408400  18378184846077171
# 3           3    300207646  17992827728271359
# 4           4   5614303926  17934860549695140
#
#                                         Comment Text             Publish Date
# 0                                          The goat!   12/25/2023, 5:55:26 PM
# 1                                           ❤️❤️❤️❤️   12/25/2023, 6:36:52 PM
# 2  Never heard of your husband. Hope he makes a g...  12/25/2023, 11:51:47 PM
# 3        This fit is everything & she is beautiful 🥰   12/26/2023, 3:24:06 AM
# 4                who’s that guy in the second photo?   12/27/2023, 1:32:42 AM

# %%
# looking at Jonathan Owens
jo.head()
# Out:
#    Unnamed: 0      User Id         Comment Id  \
# 0           0  56597613313  17908610195809218
# 1           1  56597613313  18026938972723984
# 2           2    236447151  17919327446765056
# 3           3    236447151  17989393328603270
# 4           4    236447151  17968603745528169
#
#                                         Comment Text          Publish Date
# 0                                   Beautiful couple  1/3/2024, 5:05:52 PM
# 1                                   She is the prize  1/3/2024, 5:07:22 PM
# 2  @jariruiz … You are giving yourself & these no...  1/3/2024, 5:09:57 PM
# 3  @jariruiz **only God knows what’s best for her...  1/3/2024, 5:12:15 PM
# 4  @melomatlala … I too like & admire Simone Bile...  1/3/2024, 5:16:24 PM

# %%
# listing out column names
sb.columns.to_list()
# Out:
# ['Unnamed: 0', 'User Id', 'Comment Id', 'Comment Text', 'Publish Date']

# %%
# looking at how many values we have for each column
sb.count()
# Out:
# Unnamed: 0      600
# User Id         600
# Comment Id      600
# Comment Text    598
# Publish Date    600
# dtype: int64

# %%
# looking at how many values we have for each column
jo.count()
# Out:
# Unnamed: 0      600
# User Id         600
# Comment Id      600
# Comment Text    597
# Publish Date    600
# dtype: int64

# %% [markdown]
# #Cleaning and Observing Data

# %%
# updating Publish Date to only have the date, rather than both date and time
sb['Publish Date'] = pd.to_datetime(sb['Publish Date']).dt.date
# Out:
# /var/folders/wq/0drp36md1ndchmcfz02rx9tw0000gn/T/ipykernel_2909/3441090571.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sb['Publish Date'] = pd.to_datetime(sb['Publish Date']).dt.date

# %%
sb.head()
# Out:
#    Unnamed: 0      User Id         Comment Id  \
# 0           0   4382790947  17857495791052843
# 1           1  51746321373  17860182567067690
# 2           2     28408400  18378184846077171
# 3           3    300207646  17992827728271359
# 4           4   5614303926  17934860549695140
#
#                                         Comment Text Publish Date
# 0                                          The goat!   2023-12-25
# 1                                           ❤️❤️❤️❤️   2023-12-25
# 2  Never heard of your husband. Hope he makes a g...   2023-12-25
# 3        This fit is everything & she is beautiful 🥰   2023-12-26
# 4                who’s that guy in the second photo?   2023-12-27

# %%
# updating Publish Date to only have the date, rather than both date and time
jo['Publish Date'] = pd.to_datetime(jo['Publish Date']).dt.date
jo.head()
# Out:
# /var/folders/wq/0drp36md1ndchmcfz02rx9tw0000gn/T/ipykernel_2909/2112976489.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   jo['Publish Date'] = pd.to_datetime(jo['Publish Date']).dt.date
#    Unnamed: 0      User Id         Comment Id  \
# 0           0  56597613313  17908610195809218
# 1           1  56597613313  18026938972723984
# 2           2    236447151  17919327446765056
# 3           3    236447151  17989393328603270
# 4           4    236447151  17968603745528169
#
#                                         Comment Text Publish Date
# 0                                   Beautiful couple   2024-01-03
# 1                                   She is the prize   2024-01-03
# 2  @jariruiz … You are giving yourself & these no...   2024-01-03
# 3  @jariruiz **only God knows what’s best for her...   2024-01-03
# ...

# %%
# creating histogram
plt.hist(sb['Publish Date'])
plt.xticks(rotation=45)
plt.savefig('../OUTPUT/Simone_Bile_Comment_Dates')
plt.show()

# %%
# creating histogram
plt.hist(jo['Publish Date'])
plt.xticks(rotation=45)
plt.savefig('../OUTPUT/Jonathan_Owens_Comment_Dates')
plt.show()

# %%
# adding a new column to analyze comment length
sb["Comment Length"]= sb["Comment Text"].str.len()

# %%
sb['Comment Length'].describe()
# Out:
# count     598.000000
# mean       58.306020
# std       122.963171
# min         1.000000
# 25%        15.000000
# 50%        28.000000
# 75%        61.750000
# max      1906.000000
# Name: Comment Length, dtype: float64

# %%
# adding a new column to analyze comment length
jo["Comment Length"]= jo["Comment Text"].str.len()

# %%
jo['Comment Length'].describe()
# Out:
# count    597.000000
# mean      73.787270
# std       72.792709
# min        1.000000
# 25%       25.000000
# 50%       52.000000
# 75%       98.000000
# max      537.000000
# Name: Comment Length, dtype: float64

# %%
# Creating a scatterplot of comment lengths on each profile
x = sb['Comment Length']
y = jo['Comment Length']
plt.title('Comment Length for Simone Biles and Jonathan Owens posts')
plt.xlabel("Simone Biles")
plt.ylabel("Jonathan Owens")
plt.scatter(x, y)
plt.savefig('../OUTPUT/Comment_Length_Scatter.png')
plt.show()

# %%
# looking at missing values
sb.isnull().sum()
# Out:
# Unnamed: 0        0
# User Id           0
# Comment Id        0
# Comment Text      2
# Publish Date      0
# Comment Length    2
# dtype: int64

# %%
# looking at missing values
jo.isnull().sum()
# Out:
# Unnamed: 0        0
# User Id           0
# Comment Id        0
# Comment Text      3
# Publish Date      0
# Comment Length    3
# dtype: int64

# %%
# dropping missing values
clean_sb = sb.dropna()

# %%
# confirming missing values are dropped
clean_sb.isnull().sum()
# Out:
# Unnamed: 0        0
# User Id           0
# Comment Id        0
# Comment Text      0
# Publish Date      0
# Comment Length    0
# dtype: int64

# %%
clean_sb.head()
# Out:
#    Unnamed: 0      User Id         Comment Id  \
# 0           0   4382790947  17857495791052843
# 1           1  51746321373  17860182567067690
# 2           2     28408400  18378184846077171
# 3           3    300207646  17992827728271359
# 4           4   5614303926  17934860549695140
#
#                                         Comment Text Publish Date  \
# 0                                          The goat!   2023-12-25
# 1                                           ❤️❤️❤️❤️   2023-12-25
# 2  Never heard of your husband. Hope he makes a g...   2023-12-25
# 3        This fit is everything & she is beautiful 🥰   2023-12-26
# 4                who’s that guy in the second photo?   2023-12-27
#
#    Comment Length
# 0             9.0
# 1             8.0
# 2            66.0
# 3            43.0
# 4            35.0

# %%
# dropping missing values
clean_jo = jo.dropna()

# %%
# confirming missing values are dropped
clean_jo.isnull().sum()
# Out:
# Unnamed: 0        0
# User Id           0
# Comment Id        0
# Comment Text      0
# Publish Date      0
# Comment Length    0
# dtype: int64

# %% [markdown]
# #VADER Sentiment Analysis

# %%
# installing analysis package
# !pip install vaderSentiment

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %% [markdown]
# # Simone Biles

# %%
# Create an instance of the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Define a function to perform sentiment analysis using VADER
def get_sentiment(tokens):
    sentiment = analyzer.polarity_scores(tokens)
    compound_score = sentiment['compound']
    return compound_score

# Apply the function to the 'tokens' column of the DataFrame
clean_sb['sentiment'] = clean_sb['Comment Text'].apply(get_sentiment)

# Print the DataFrame with sentiment scores
print(clean_sb['sentiment'])
# Out:
# 0      0.0000
# 1      0.0000
# 2      0.7003
# 3      0.9287
# 4      0.0000
#         ...
# 595    0.0000
# 596    0.9788
# 597    0.5994
# 598    0.0000
# 599    0.5994
# Name: sentiment, Length: 598, dtype: float64
# /var/folders/wq/0drp36md1ndchmcfz02rx9tw0000gn/T/ipykernel_2909/1800835897.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_sb['sentiment'] = clean_sb['Comment Text'].apply(get_sentiment)

# %%
# create positive, neutral, negative columns 
clean_sb['sent'] = np.where(clean_sb['sentiment'] > 0.05, "Positive",
                            np.where(clean_sb['sentiment'] < -0.05, "Negative", "Neutral"))
clean_sb.sent.value_counts()
# Out:
# /var/folders/wq/0drp36md1ndchmcfz02rx9tw0000gn/T/ipykernel_2909/3744696477.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_sb['sent'] = np.where(clean_sb['sentiment'] > 0.05, "Positive",
# sent
# Positive    369
# Neutral     155
# Negative     74
# Name: count, dtype: int64

# %%
# Count the occurrences of each sentiment
sentiment_counts = clean_sb['sent'].value_counts()

# Plot the sentiments
plt.bar(sentiment_counts.index, sentiment_counts.values)
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Sentiment Analysis on Simone Biles')
plt.ylim([0, 375])
plt.savefig('../OUTPUT/Simone_Biles_Sentiment_Analysis.png')
plt.show()


# Print the number of counts for each sentiment
for sentiment, count in sentiment_counts.items():
    print(f"{sentiment}: {count}")
# Out:
# Positive: 369
# Neutral: 155
# Negative: 74

# %% [markdown]
# # Jonathan Owens

# %%
# Create an instance of the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Define a function to perform sentiment analysis using VADER
def get_sentiment(tokens):
    sentiment = analyzer.polarity_scores(tokens)
    compound_score = sentiment['compound']
    return compound_score

# Apply the function to the 'tokens' column of the DataFrame
clean_jo['sentiment'] = clean_jo['Comment Text'].apply(get_sentiment)

# Print the DataFrame with sentiment scores
print(clean_jo['sentiment'])
# Out:
# 0      0.5994
# 1      0.5106
# 2      0.8513
# 3      0.7430
# 4      0.8519
#         ...
# 595   -0.3464
# 596    0.0000
# 597    0.0000
# 598   -0.3400
# 599    0.3818
# Name: sentiment, Length: 597, dtype: float64
# /var/folders/wq/0drp36md1ndchmcfz02rx9tw0000gn/T/ipykernel_2909/1332806252.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_jo['sentiment'] = clean_jo['Comment Text'].apply(get_sentiment)

# %%
# create positive, neutral, negative columns 
clean_jo['sent'] = np.where(clean_jo['sentiment'] > 0.05, "Positive",
                            np.where(clean_jo['sentiment'] < -0.05, "Negative", "Neutral"))
clean_jo.sent.value_counts()
# Out:
# /var/folders/wq/0drp36md1ndchmcfz02rx9tw0000gn/T/ipykernel_2909/1352062398.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_jo['sent'] = np.where(clean_jo['sentiment'] > 0.05, "Positive",
# sent
# Positive    241
# Neutral     192
# Negative    164
# Name: count, dtype: int64

# %%
# Count the occurrences of each sentiment
sentiment_counts = clean_jo['sent'].value_counts()

# Plot the sentiments
plt.bar(sentiment_counts.index, sentiment_counts.values)
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Sentiment Analysis on Jonathan Owens')
plt.ylim([0, 375])
plt.savefig('../OUTPUT/Jonathan_Owens_Sentiment_Analysis')
plt.show()



# Print the number of counts for each sentiment
for sentiment, count in sentiment_counts.items():
    print(f"{sentiment}: {count}")
# Out:
# Positive: 241
# Neutral: 192
# Negative: 164

# %% [markdown]
# # Playing with word clouds

# %%
! pip install wordcloud

# %%
# import word cloud code
from wordcloud import WordCloud

# %% [markdown]
# Creating a Word Cloud for comments from Simone Biles' posts

# %%
simone_cloud = " ".join(comment for comment in clean_sb['Comment Text'])

# Creating word_cloud with text as argument in .generate() method

simone_word_cloud = WordCloud(collocations = False, background_color = 'white').generate(simone_cloud)

# Display the generated Word Cloud

plt.imshow(simone_word_cloud, interpolation='bilinear')

plt.axis("off")
plt.savefig("../OUTPUT/Simone_Biles_Word_Cloud")
plt.show()

# %% [markdown]
# Creating a Word Cloud for comments under Jonathan Owens' posts

# %%
jonathan_cloud = " ".join(comment for comment in clean_jo['Comment Text'])

# Creating word_cloud with text as argument in .generate() method

jonathan_word_cloud = WordCloud(collocations = False, background_color = 'white').generate(jonathan_cloud)

# Display the generated Word Cloud

plt.imshow(jonathan_word_cloud, interpolation='bilinear')

plt.axis("off")
plt.savefig("../OUTPUT/Jonathan_Owens_Word_Cloud")
plt.show()

# %% [markdown]
# # Exporting Data

# %%
clean_sb.to_csv('../DATA/clean_sb.csv')
clean_jo.to_csv('../DATA/clean_jo.csv')
